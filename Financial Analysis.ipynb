# %% [markdown]
# ### Importing Libraries

# %%
# import all packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
import os

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv('Financial_Sample.csv')

# %% [markdown]
# ### Data Exploration

# %%
sns.set_style('darkgrid')

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   700.000000           700.000000  700.000000  7.000000e+02
# mean   1608.294286            96.477143  118.428571  1.827594e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1542.500000            10.000000   20.000000  3.798000e+04
# 75%    2229.125000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
# std     867.427859           108.602612  136.775515  2.542623e+05
#
#            Discounts         Sales           COGS         Profit  \
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# 25%       800.320000  1.592800e+04    7490.000000    2805.960000
# ...

# %%
df.dtypes
# Out:
# Segment                 object
# Country                 object
# Product                 object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price      int64
# Sale Price               int64
# Gross Sales            float64
# Discounts              float64
#  Sales                 float64
# COGS                   float64
# Profit                 float64
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %%
# To drop unwanted columns
# df.drop(['Discount Band'], axis = 1, inplace = True)

# %%
# To replace all the empty columns

#df = df.replace(r'^\s*$', np.nan, regex = True)

# %% [markdown]
# ### Data Visualization

# %%
sns.countplot(x = 'Segment', data = df, linewidth = 3, palette = "Set2", edgecolor = 'black')
plt.show;
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x = 'Manufacturing Price', data = df, palette = "mako", linewidth = 2, edgecolor = "black")
plt.show();

# %%
# Analyzing the products and discount band by segment.

plt.figure(figsize = (18,6))
plt.subplot(1,2,1)
sns.countplot(x = df['Segment'], hue = df['Product'], palette = 'rocket', linewidth = 3, edgecolor = "white")
plt.title("Products")

plt.subplot(1,2,2)
sns.countplot(x = df['Segment'], hue = df['Discount Band'], palette = 'hot', linewidth = 3, edgecolor = 'white')
plt.title("Discount Band")
plt.show;

# %%
# Counting the years the products were sold

sns.countplot(x = df['Year'], palette = 'icefire', linewidth = 2, edgecolor = "black")
plt.show()

# %%
# Analyizng the products by date sold

plt.figure(figsize=(10, 6))
sns.histplot(df['Date'], color = 'darkred')
plt.title('Products By Date Sold')
plt.show()

# %%
# Analyzing the profit obtained in each month

sns.barplot(data = df, x = 'Profit', y = 'Month Name', color = 'tomato')
plt.title('Months Products were Sold By Profit')
plt.xlabel('Profit')
plt.ylabel('Month Name');

# %%
# Analyzing the profit made by each product.

plt.scatter(data = df, x = 'Product', y = 'Profit', color = 'brown')
plt.title('Profit By Products')
plt.xlabel('Product')
plt.ylabel('Profit');

# %%
# Analzing the profit made by each segment.

plt.scatter(data = df, x = 'Segment', y = 'Profit', color = 'brown')
plt.title('Profit By Segment')
plt.xlabel('Segment')
plt.ylabel('Profit');

# %%
# Analyzing the products by sale price.

plt.figure(figsize = (16,8))
sns.pointplot(x = "Product", y = "Sale Price", data = df, linestyles = "--", capsize = .3, color = 'orangered')
plt.title("Sale Price By Product")
plt.show()

# %%
# Analyzing segment by year and discount band by products.

plt.figure(figsize = (18,6))
plt.subplot(1,2,1)
sns.countplot(hue = df['Segment'], x = df['Year'], palette = 'viridis', linewidth = 2, edgecolor = "black")
plt.title("DURATION")

plt.subplot(1,2,2)
sns.countplot(hue = df['Product'], x = df['Discount Band'], palette = 'seismic', linewidth = 2, edgecolor = "black")
plt.title("DISCOUNT BAND BY PRODUCT")
plt.show();
